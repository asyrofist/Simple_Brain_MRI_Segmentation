# %%
import cv2
import matplotlib.pyplot as plt

image1 = cv2.imread('C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\hasil_perc17.jpeg', 0)
image2 = cv2.imread('C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\hasil_perc3.jpeg', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image1)
plt.subplot(2,2,2)
plt.imshow(image2)

# %%
import numpy as np

def dice(im1, im2, empty_score=1.0):
    im1 = np.asarray(im1).astype(np.bool)
    im2 = np.asarray(im2).astype(np.bool)

    if im1.shape != im2.shape:
        raise ValueError("Shape mismatch: im1 and im2 must have the same shape.")        
    im_sum = im1.sum() + im2.sum()

    if im_sum == 0:
        return empty_score

    # Compute Dice coefficient
    intersection = np.logical_and(im1, im2)
    return 2. * intersection.sum() / im_sum

# %%
dice(image1,image2)
# Out:
# 1.0
