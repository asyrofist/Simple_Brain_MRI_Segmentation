# %%
import cv2
import matplotlib.pyplot as plt
path = "C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\"
image1 = cv2.imread(path + 'hasil_perc17.jpeg', 0)
image2 = cv2.imread(path + 'hasil_perc3.jpeg', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image1)
plt.subplot(2,2,2)
plt.imshow(image2)

# %%
import numpy as np
im1 = np.asarray(image1)
print(im1)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
im2 = np.asarray(image2)
print(im2)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
a = im1.sum()
b = im2.sum()
im_sum = a + b
print(a, "nilai gambar1")
print(b, "nilai gambar2")
print(im_sum)

inter = a & b
print(inter, "intersaction")
formula = ((2*inter) / im_sum )
print(formula, "DSI")
# Out:
# 2699239 nilai gambar1
# 2783972 nilai gambar2
# 5483211
# 2632420 intersaction
# 0.9601746130141627 DSI

# %%
import numpy as np

def dice(im1, im2, empty_score=1.0):
    im1 = np.asarray(im1).astype(np.bool)
    im2 = np.asarray(im2).astype(np.bool)

    if im1.shape != im2.shape:
        raise ValueError("Shape mismatch: im1 and im2 must have the same shape.")        
    im_sum = im1.sum() + im2.sum()

    if im_sum == 0:
        return empty_score

    # Compute Dice coefficient
    intersection = np.logical_and(im1, im2)
    return 2. * intersection.sum() / im_sum

# %%
dice(image1,image2)
# Out:
# 0.9999847409781033

# %%
path = "C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\"
image3 = cv2.imread(path + 'hasil_perc15.jpeg', 0)
image4 = cv2.imread(path + 'hasil_perc19.jpeg', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image3)
plt.subplot(2,2,2)
plt.imshow(image4)

# %%
im3 = np.asarray(image3)
print(im3)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
im4 = np.asarray(image4)
print(im4)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
a = im3.sum()
b = im4.sum()
im_sum = a + b
print(a, "nilai gambar1")
print(b, "nilai gambar2")
print(im_sum)

inter = a & b
print(inter, "intersaction")
formula = ((2*inter) / im_sum )
print(formula, "DSI")
# Out:
# 2948310 nilai gambar1
# 3013291 nilai gambar2
# 5961601
# 2947202 intersaction
# 0.9887283634043942 DSI

# %%
dice(image3, image4)
# Out:
# 0.9999923705472606

# %%
path = "C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\"
image1 = cv2.imread(path + 'hasil_perc17.jpeg', 0)
image3 = cv2.imread(path + 'hasil_perc15.jpeg', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image1)
plt.subplot(2,2,2)
plt.imshow(image3)

# %%
a = im1.sum()
b = im3.sum()
im_sum = a + b
print(a, "nilai gambar1")
print(b, "nilai gambar2")
print(im_sum)

inter = a & b
print(inter, "intersaction")
formula = ((2*inter) / im_sum )
print(formula, "DSI")
# Out:
# 2699239 nilai gambar1
# 2948310 nilai gambar2
# 5647549
# 2632902 intersaction
# 0.9324051902869723 DSI

# %%
path = "C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\"
image5 = cv2.imread(path + 'hasil_perc17.jpeg', 0)
image6 = cv2.imread(path + 'hasil_perc23a.jpeg', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image5)
plt.subplot(2,2,2)
plt.imshow(image6)

# %%
im5 = np.asarray(image5)
print(im5)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
im6 = np.asarray(image6)
print(im6)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
a = im5.sum()
b = im6.sum()
im_sum = a + b
print(a, "nilai gambar1")
print(b, "nilai gambar2")
print(im_sum)

inter = a & b
print(inter, "intersaction")
formula = ((2*inter) / im_sum )
print(formula, "DSI")
# Out:
# 2699239 nilai gambar1
# 2881476 nilai gambar2
# 5580715
# 2697156 intersaction
# 0.9665987243570044 DSI

# %%
dice(image5, image6)
# Out:
# 0.9999771112925253

# %%
path = "C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\"
image7 = cv2.imread(path + 'hasil_perc23.jpeg', 0)
image8 = cv2.imread(path + 'hasil_perc23b.jpeg', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image7)
plt.subplot(2,2,2)
plt.imshow(image8)

# %%
im7 = np.asarray(image7)
print(im7)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
im8 = np.asarray(image8)
print(im8)
# Out:
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  ...
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]
#  [30 30 30 ... 30 30 30]]

# %%
a = im7.sum()
b = im8.sum()
im_sum = a + b
print(a, "nilai gambar7")
print(b, "nilai gambar8")
print(im_sum)

inter = a & b
print(inter, "intersaction")
formula = ((2*inter) / im_sum )
print(formula, "DSI")
# Out:
# 2127491 nilai gambar7
# 2110980 nilai gambar8
# 4238471
# 2110976 intersaction
# 0.996102603981483 DSI

# %%
dice(image7,image8)
# Out:
# 0.9999923705472606

# %%
import cv2
import matplotlib.pyplot as plt
path = "C:\\Users\\Asus\\Desktop\\tugas\\RPLB (python)\\Simple_Brain_MRI_Segmentation\\experiment\\"
image7 = cv2.imread(path + 'hasil_perc17.jpeg', 0)
image8 = cv2.imread(path + 'Screenshot_94.png', 0)

fig=plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)
plt.imshow(image7)  
plt.subplot(2,2,2)
plt.imshow(image8)

# %%
dice(image7, image8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-e6ada1795315> in <module>
# ----> 1 dice(image7, image8)
#
# <ipython-input-49-0ccf2a89d5b1> in dice(im1, im2, empty_score)
#       6
#       7     if im1.shape != im2.shape:
# ----> 8         raise ValueError("Shape mismatch: im1 and im2 must have the same shape.")
#       9     im_sum = im1.sum() + im2.sum()
#      10
#
# ValueError: Shape mismatch: im1 and im2 must have the same shape.
